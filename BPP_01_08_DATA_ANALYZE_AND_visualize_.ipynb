# %% [markdown]
# <a href="https://colab.research.google.com/github/nilanusrat/bpp-01-08-DataAnalysisAndVisualize/blob/main/BPP_01_08_DATA_ANALYZE_AND_visualize_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Out:
# --2024-12-21 04:39:12--  https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133023 (130K) [text/plain]
# Saving to: ‘student_data.csv.1’
#
# student_data.csv.1  100%[===================>] 129.91K  --.-KB/s    in 0.03s
#
# 2024-12-21 04:39:12 (4.94 MB/s) - ‘student_data.csv.1’ saved [133023/133023]

# %%
df = pd.read_csv("student_data.csv")
df.head()
df.sample(5)
# Out:
#       id first_name last_name                         email      gender  \
# 998  999    Malvina      Tuhy         mtuhyrq@bloglines.com  Non-binary
# 940  941     Freddi   Luxford           fluxfordq4@java.com      Female
# 765  766     Carita    Gouley        cgouleyl9@columbia.edu      Female
# 379  380       Tiff     Bayns          tbaynsaj@behance.net      Female
# 476  477     Corrie    Hedaux  chedauxd8@chicagotribune.com        Male
#
#           ip_address  cgpa  passing_year        department  attendance  \
# 998     49.201.10.99   NaN        2017.0          Medicine       61.29
# 940  192.173.224.158  3.14        2023.0  Computer Science       66.70
# 765  135.180.210.246  1.87        2025.0  Computer Science       88.29
# 379    191.214.140.7   NaN        2004.0          Business       33.34
# 476    72.183.226.63  3.51        2005.0              Arts       39.56
#
#     home_district  abroad_study  student_id  graduation_date  \
# ...

# %%
#Print the student list where student_id >500
filtered_df = df[df['student_id'] > 500]
print(filtered_df)
# Out:
#        id  first_name  last_name                     email      gender  \
# 500   501        Amos     Yedall     ayedalldw@pcworld.com        Male
# 501   502  Sutherland    Gullyes    sgullyesdx@answers.com        Male
# 502   503     Paolina   Langmaid  plangmaiddy@google.co.uk      Female
# 503   504        Ciro  Blackmuir    cblackmuirdz@github.io        Male
# 504   505      Archer      Eeles        aeelese0@youku.com        Male
# ..    ...         ...        ...                       ...         ...
# 995   996   Catharina    Bradtke    cbradtkern@pcworld.com      Female
# 996   997   Anastasia      Lowde         alowdero@blog.com      Female
# 997   998       Tandi   Whitlock   twhitlockrp@skyrock.com      Female
# 998   999     Malvina       Tuhy     mtuhyrq@bloglines.com  Non-binary
# 999  1000      Kissee   Okeshott       kokeshottrr@msu.edu      Female
#
#           ip_address  cgpa  passing_year        department  attendance  \
# ...

# %%
# display all stufents who have a passing year after 2019
import pandas as pd
filtered_df = df[df['passing_year'] > 2019]
print(filtered_df)
# Out:
#       id first_name   last_name                          email  gender  \
# 1      2         Si     Skottle      sskottle1@squarespace.com    Male
# 3      4     Shadow      Scarff           sscarff3@walmart.com    Male
# 4      5      Karim  Domenicone      kdomenicone4@sakura.ne.jp    Male
# 5      6    Ottilie       Adlem              oadlem5@house.gov  Female
# 10    11         Vi     Drinnan            vdrinnana@fotki.com  Female
# ..   ...        ...         ...                            ...     ...
# 986  987     Shelba     Barthod            sbarthodre@admin.ch  Female
# 989  990     Rodger    Baudassi  rbaudassirh@timesonline.co.uk    Male
# 990  991   Frederik     Baltzar      fbaltzarri@shareasale.com    Male
# 992  993     Howard     Lankham           hlankhamrk@prlog.org    Male
# 997  998      Tandi    Whitlock        twhitlockrp@skyrock.com  Female
#
#           ip_address  cgpa  passing_year        department  attendance  \
# ...

# %%
# Calculate the maximum attendance rate
attendance_data = [61.29, 66.70, 882.9, 33.34, 39.56]
df = pd.DataFrame(attendance_data, columns=['attendance_rate'])
max_attendance_rate = df['attendance_rate'].max()

print(f"The maximum attendance rate is: {max_attendance_rate}%")
# Out:
# The maximum attendance rate is: 882.9%

# %%
# create a new column for students who have a CGPA greater than 3.5 ( marked as "HIgh CGPA ")

import pandas as pd
import numpy as np

data = {'CGPA': [np.nan, 3.14, 1.87, np.nan, 3.51]}
df = pd.DataFrame(data)

df['CGPA'].fillna(0, inplace=True)

df['High CGPA'] = df['CGPA'] > 3.5

print(df)
# Out:
#    CGPA  High CGPA
# 0  0.00      False
# 1  3.14      False
# 2  1.87      False
# 3  0.00      False
# 4  3.51       True
# <ipython-input-8-06034dfc1c5f>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CGPA'].fillna(0, inplace=True)

# %%
# Generate a line graph of CGPA trends over the years
import matplotlib.pyplot as plt

years = [2008, 2016, 2005, 2013, 2012]
cgpa = [2.8, 3.1, 3.3, 3.4, 3.5]  # Sample CGPA values

plt.plot(years, cgpa, marker='o', linestyle='-', color='b')

plt.title('CGPA Trends Over the Years')
plt.xlabel('Year')
plt.ylabel('CGPA')

plt.grid(True)
plt.show()
